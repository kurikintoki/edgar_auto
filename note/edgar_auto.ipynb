# %%
# %cd /content/drive/MyDrive/11_Python_projects/edgar_auto/

from edgar_fs import *
# Out:
# /content/drive/MyDrive/11_Python_projects/edgar_auto

# %%
#cik = '0000320193' # apple
#cik = '0001326801' # facebook
#cik = '0000789019' # microsoft
#cik = '0001652044' # alphabet
cik = '0001018724' # amazon
#cik = '0001067983' # berkshire hathaway
#cik = '0000040545' # ge
#cik = '0001650372' # atlassian
#cik = '0001467623' # dropbox
#cik = '0001372612' # box
#cik = '0001341439' # oracle
#cik = '0001108524' # salesforce
#cik = '0001059556' # moodys
#cik = '0000059478' # eli lilly
#cik = '0001065280' # netflix
#cik = '0001364742' # blackrock
#cik = '0000773840' # honeywell international
#cik = '0001318605' # tesla
#cik = '0000320187' # nike
#cik = '0001512673' # square
#cik = '0001633917' # paypal

# %%
edgar_fs = EdgarFS(cik)

# %%
edgar_fs.urls_df['Base'].values
# Out:
# array(['https://www.sec.gov/Archives/edgar/data/1018724/000101872421000004',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872420000004',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872419000004',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872418000005',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872417000011',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872416000172',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872415000006',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000101872414000006',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000119312513028520',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000119312512032846',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000119312511016253',
#        'https://www.sec.gov/Archives/edgar/data/1018724/000119312510016098',
# ...

# %%
df = edgar_fs.to_dataframe()
# Out:
# The HTTP code 404 occurs. Please check the year and url:  2009 https://www.sec.gov/Archives/edgar/data/1018724/000119312509014406/FilingSummary.xml
# The HTTP code 404 occurs. Please check the year and url:  2008 https://www.sec.gov/Archives/edgar/data/1018724/000119312508024707/FilingSummary.xml
# The HTTP code 404 occurs. Please check the year and url:  2007 https://www.sec.gov/Archives/edgar/data/1018724/000119312507034081/FilingSummary.xml
# The HTTP code 404 occurs. Please check the year and url:  2006 https://www.sec.gov/Archives/edgar/data/1018724/000119312506034166/FilingSummary.xml
# The HTTP code 404 occurs. Please check the year and url:  2005 https://www.sec.gov/Archives/edgar/data/1018724/000119312505047032/FilingSummary.xml
# The HTTP code 404 occurs. Please check the year and url:  2004 https://www.sec.gov/Archives/edgar/data/1018724/000119312504029488/FilingSummary.xml
# ...

# %%
df
# Out:
#                                              2021   2020  ...         2017   2016
# Revenue                                     21454  17772  ...  10842000000   9248
# Income from Operations                       3289   2719  ...   1586000000   1461
# Net income                                   4202   2459  ...   1401000000   1228
# Total stockholders' equity                  20063  16929  ...        14712  13759
# Total liabilities and stockholders' equity  70379  51333  ...        33103  28881
# Net cash provided by operating activities    5854   4561  ...         3158   2546
# Operating margin                            15.33   15.3  ...        14.63   15.8
# ROE                                         22.72  15.22  ...  9.84159e+06    NaN
# Shareholders' equity ratio                  28.51  32.98  ...        44.44  47.64
#
# [9 rows x 6 columns]

# %%
edgar_fs.urls_df
# Out:
#                                                    Base  ...                           Statements of cash flows
# 2021  https://www.sec.gov/Archives/edgar/data/163391...  ...  https://www.sec.gov/Archives/edgar/data/163391...
# 2020  https://www.sec.gov/Archives/edgar/data/163391...  ...  https://www.sec.gov/Archives/edgar/data/163391...
# 2019  https://www.sec.gov/Archives/edgar/data/163391...  ...  https://www.sec.gov/Archives/edgar/data/163391...
# 2018  https://www.sec.gov/Archives/edgar/data/163391...  ...  https://www.sec.gov/Archives/edgar/data/163391...
# 2017  https://www.sec.gov/Archives/edgar/data/163391...  ...  https://www.sec.gov/Archives/edgar/data/163391...
# 2016  https://www.sec.gov/Archives/edgar/data/163391...  ...                                               None
#
# [6 rows x 6 columns]

# %%
edgar_fs.urls_df.loc['2017'].values
# Out:
# array(['https://www.sec.gov/Archives/edgar/data/1633917/000163391717000027',
#        'https://www.sec.gov/Archives/edgar/data/1633917/000163391717000027/FilingSummary.xml',
#        'https://www.sec.gov/Archives/edgar/data/1633917/000163391717000027/0001633917-17-000027-index.htm',
#        'https://www.sec.gov/Archives/edgar/data/1633917/000163391717000027/R4.htm',
#        'https://www.sec.gov/Archives/edgar/data/1633917/000163391717000027/R2.htm',
#        'https://www.sec.gov/Archives/edgar/data/1633917/000163391717000027/R7.htm'],
#       dtype=object)
